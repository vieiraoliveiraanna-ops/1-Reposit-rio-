# %% [markdown]
# <a href="https://colab.research.google.com/github/vieiraoliveiraanna-ops/1-Reposit-rio-/blob/main/ejercicios/02/Sistemas%20de%20cifrado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
senha = "123456"
senha_criptografada = " "
for numero in senha:
  numero = int(numero) + 1
  senha_criptografada = senha_criptografada + str(numero)
print (senha_criptografada)
# Out:
#  234567
